# %% [markdown]
# <a href="https://colab.research.google.com/github/parthsharmaww-ai/Stock-Direction-Predictor/blob/main/notebooks/01_project_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stage 1 — Project Setup
#
# This notebook verifies the environment, installs libraries,
# and confirms data access for the stock direction predictor project.
#
# **Asset:** Nifty 50 (^NSEI)
# **Prediction target:** Next-day price direction (up = 1, down = 0)
# **Data source:** Yahoo Finance via yfinance

# %%
# Install required libraries
# !pip install yfinance pandas numpy scikit-learn matplotlib seaborn --quiet

print("Installation complete ✓")
# Out:
# Installation complete ✓

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("yfinance:", yf.__version__)
print("All imports successful ✓")
# Out:
# pandas: 2.2.2
# numpy: 2.0.2
# yfinance: 0.2.66
# All imports successful ✓

# %%
# Download 1 month of Nifty 50 data as a sanity check
df_test = yf.download("^NSEI", start="2024-01-01", end="2024-01-31")

print("Shape:", df_test.shape)
print("\nFirst 5 rows:")
print(df_test.head())
print("\nColumn names:", df_test.columns.tolist())
print("\nAny missing values?", df_test.isnull().sum().sum())
# Out:
# /tmp/ipykernel_7790/2875853644.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_test = yf.download("^NSEI", start="2024-01-01", end="2024-01-31")
# [*********************100%***********************]  1 of 1 completed
# Shape: (20, 5)
#
# First 5 rows:
# Price              Close          High           Low          Open  Volume
# Ticker             ^NSEI         ^NSEI         ^NSEI         ^NSEI   ^NSEI
# Date
# 2024-01-01  21741.900391  21834.349609  21680.849609  21727.750000  154000
# 2024-01-02  21665.800781  21755.599609  21555.650391  21751.349609  263700
# 2024-01-03  21517.349609  21677.000000  21500.349609  21661.099609  311900
# 2024-01-04  21658.599609  21685.650391  21564.550781  21605.800781  339200
# 2024-01-05  21710.800781  21749.599609  21629.199219  21705.750000  309300
#
# Column names: [('Close', '^NSEI'), ('High', '^NSEI'), ('Low', '^NSEI'), ('Open', '^NSEI'), ('Volume', '^NSEI')]
#
# Any missing values? 0

# %% [markdown]
# ## Notes
#
# - Data loads successfully from Yahoo Finance
# - Nifty 50 ticker confirmed as ^NSEI
# - Full data pull (2019–2024) will happen in Stage 2
# - Next step: exploratory data analysis and cleaning
